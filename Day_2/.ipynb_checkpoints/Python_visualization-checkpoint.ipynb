# %%
#to display SVG images
from IPython.display import SVG

# %%
#import pandas & pygal
import pandas as pd
import pygal

# %%
#reading data in Day_2 folder and place in variable
health_data = pd.read_csv('Dem_Health_Full.txt',sep='\t')

# %%
#view data from Dem_Health_Full.txt using variable health_data
health_data.head(2)#prints first /num of/ lines based on (argument), default () is five
health_data.tail(2)#prints last /num of/ lines based on (argument), default () is five
# Out:
#         County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 3139  Washakie    WY                   4     11.1               9.1     14.1
# 3140    Weston    WY                   3      9.9              11.7     15.8
#
#       Total_Births  Total_Deaths
# 3139         974.0         844.0
# 3140         670.0         629.0

# %%
#prints the column labeled as State
health_data['State']
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AL
# 16      AL
# 17      AL
# 18      AL
# 19      AL
# 20      AL
# 21      AL
# 22      AL
# 23      AL
# 24      AL
# 25      AL
# 26      AL
# 27      AL
# 28      AL
# 29      AL
#         ..
# 3111    WI
# 3112    WI
# 3113    WI
# 3114    WI
# 3115    WI
# 3116    WI
# 3117    WI
# 3118    WY
# 3119    WY
# 3120    WY
# 3121    WY
# 3122    WY
# 3123    WY
# 3124    WY
# 3125    WY
# 3126    WY
# 3127    WY
# 3128    WY
# 3129    WY
# 3130    WY
# 3131    WY
# 3132    WY
# 3133    WY
# 3134    WY
# 3135    WY
# 3136    WY
# 3137    WY
# 3138    WY
# 3139    WY
# 3140    WY
# Name: State, dtype: object

# %%
#prints columns labeled state and Poverty
health_data.head()[['State','Poverty']]
# Out:
#   State  Poverty
# 0    AL     10.4
# 1    AL     10.2
# 2    AL     22.1
# 3    AL     16.8
# 4    AL     11.9

# %%
#using loc understands/works only with Strings
health_data.loc[0,['Population_Density','Poverty']]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
#iloc- understand/works only integers
health_data.iloc[0,2:4]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
#selects by looking in 'States' column for TX and AL then prints
health_data[(health_data['State']=='TX')|(health_data['State']=='AL')]
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 0        Autauga    AL                  82     10.4               5.9
# 1        Baldwin    AL                 102     10.2               7.1
# 2        Barbour    AL                  32     22.1               7.1
# 3           Bibb    AL                  35     16.8               9.8
# 4         Blount    AL                  86     11.9               9.0
# 5        Bullock    AL                  18     26.2              13.3
# 6         Butler    AL                  27     20.0               5.8
# 7        Calhoun    AL                 184     16.4               9.5
# 8       Chambers    AL                  59     16.2               7.5
# 9       Cherokee    AL                  44     15.2               7.4
# 10       Chilton    AL                  60     14.9              10.5
# 11       Choctaw    AL                  16     18.7              10.8
# ...

# %%
#cleaning data
health_data.fillna(0, inplace=True)#takes two variables, first to replace NaN and second
health_data.iloc[3126]
# Out:
# County                Hot Springs
# State                          WY
# Population_Density              2
# Poverty                      11.6
# Infant_Mortality                0
# Suicide                      23.9
# Total_Births                  437
# Total_Deaths                  627
# Name: 3126, dtype: object

# %%
health_data.tail(20)
# Out:
#            County State  Population_Density  Poverty  Infant_Mortality  \
# 3121       Carbon    WY                   2     12.2               8.8
# 3122     Converse    WY                   3     10.5               7.5
# 3123        Crook    WY                   2      8.5               0.0
# 3124      Fremont    WY                   4     12.9               9.4
# 3125       Goshen    WY                   6     14.6               7.7
# 3126  Hot Springs    WY                   2     11.6               0.0
# 3127      Johnson    WY                   2      9.6               0.0
# 3128      Laramie    WY                  32      9.9               6.5
# 3129      Lincoln    WY                   4      9.5               6.4
# 3130      Natrona    WY                  13     12.1               4.9
# 3131     Niobrara    WY                   1     14.1               0.0
# 3132         Park    WY                   4     11.7               3.9
# ...

# %%
#cleaning suicide rates
health_data.head(6)
health_data['Suicide'].replace (-1111.1,0,inplace=True)#first argument is the user choice to replace,
#second is the new argument that is being placed inside, .replaces goes only to the specific first argument
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
# 2  Barbour    AL                  32     22.1               7.1     10.3
# 3     Bibb    AL                  35     16.8               9.8     14.8
# 4   Blount    AL                  86     11.9               9.0     14.4
# 5  Bullock    AL                  18     26.2              13.3      0.0
#
#    Total_Births  Total_Deaths
# 0        3048.0        1867.0
# 1        5471.0        4388.0
# 2        1835.0        1538.0
# 3        2801.0        2012.0
# 4        3318.0        2453.0
# 5        1604.0        1381.0

# %%
#tuple??
a_tuple =(1,2)
a_tuple
a_list = [1,2]
type(a_list)
nested_list = [(1,2),(3,4)]
nested_list
# Out:
# [(1, 2), (3, 4)]

# %%
#declaring a variable and placing data from only State of AL into variable
data_for_al = \
health_data.loc[health_data['State'] == 'AL', ['Population_Density','Poverty']]
data_for_al.head()
# Out:
#    Population_Density  Poverty
# 0                  82     10.4
# 1                 102     10.2
# 2                  32     22.1
# 3                  35     16.8
# 4                  86     11.9

# %%
#for loop, that will use variable x, that will be placed in variable 'lst' as a list due to []
lst = [tuple(x) for x in data_for_al.values]
lst
# Out:
# [(82.0, 10.4),
#  (102.0, 10.199999999999999),
#  (32.0, 22.100000000000001),
#  (35.0, 16.800000000000001),
#  (86.0, 11.9),
#  (18.0, 26.199999999999999),
#  (27.0, 20.0),
#  (184.0, 16.399999999999999),
#  (59.0, 16.199999999999999),
#  (44.0, 15.199999999999999),
#  (60.0, 14.9),
#  (16.0, 18.699999999999999),
#  (22.0, 19.199999999999999),
#  (23.0, 14.0),
#  (26.0, 14.0),
#  (67.0, 13.699999999999999),
#  (92.0, 14.0),
#  (16.0, 22.0),
#  (17.0, 13.4),
#  (36.0, 17.5),
#  (23.0, 17.600000000000001),
#  (108.0, 13.300000000000001),
#  (87.0, 15.800000000000001),
#  (45.0, 25.0),
#  (86.0, 15.1),
#  (119.0, 12.5),
#  (40.0, 18.600000000000001),
#  (193.0, 15.699999999999999),
#  (29.0, 16.100000000000001),
#  (48.0, 17.399999999999999),
#  (45.0, 17.600000000000001),
#  (15.0, 24.899999999999999),
#  (28.0, 20.600000000000001),
#  (30.0, 16.300000000000001),
#  (162.0, 15.300000000000001),
#  (50.0, 14.5),
#  (591.0, 14.4),
#  (25.0, 16.100000000000001),
#  (131.0, 15.6),
# ...

# %%
#creating scatter plot, stroke=False is an argument sent to .XY
scatter_plot = pygal.XY(stroke=False)
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
#labeling on graph
scatter_plot = pygal.XY(stroke=False, x_title='Population Density', y_title='Poverty')
scatter_plot.title = 'Population Density vs Poverty Correlation'
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
TX_tuple = (1,2)
TX_tuple
TX_lst = [1,2]
type(TX_lst)
TX_nested_lst =[(1,2),(3,4)]
TX_nested_lst

data_for_TX = \
health_data.loc[health_data['State'] == 'TX', ['Population_Density','Poverty']]
data_for_al.head()
# Out:
#    Population_Density  Poverty
# 0                  82     10.4
# 1                 102     10.2
# 2                  32     22.1
# 3                  35     16.8
# 4                  86     11.9

# %%
tx_lst = [tuple(y) for y in data_for_TX.values]
tx_lst
# Out:
# [(53.0, 20.100000000000001),
#  (8.0, 15.0),
#  (102.0, 17.300000000000001),
#  (98.0, 18.5),
#  (10.0, 9.0999999999999996),
#  (2.0, 9.6999999999999993),
#  (35.0, 19.0),
#  (40.0, 11.300000000000001),
#  (8.0, 17.899999999999999),
#  (25.0, 12.4),
#  (79.0, 12.6),
#  (4.0, 16.699999999999999),
#  (37.0, 24.600000000000001),
#  (242.0, 14.800000000000001),
#  (1218.0, 17.600000000000001),
#  (13.0, 10.5),
#  (1.0, 6.9000000000000004),
#  (18.0, 14.300000000000001),
#  (102.0, 17.5),
#  (201.0, 11.5),
#  (267.0, 18.899999999999999),
#  (1.0, 17.5),
#  (2.0, 15.699999999999999),
#  (8.0, 29.5),
#  (41.0, 18.100000000000001),
#  (26.0, 15.5),
#  (42.0, 11.9),
#  (67.0, 14.699999999999999),
#  (40.0, 16.300000000000001),
#  (15.0, 14.300000000000001),
#  (418.0, 29.5),
#  (62.0, 18.199999999999999),
#  (7.0, 9.0),
#  (32.0, 17.399999999999999),
#  (9.0, 19.699999999999999),
#  (47.0, 10.6),
#  (46.0, 18.199999999999999),
#  (11.0, 21.199999999999999),
#  (10.0, 11.1),
# ...

# %%
scatter_plot=pygal.XY(stroke= False, x_title='Population Density',y_title='Poverty')
scatter_plot.title = 'Pooulation Density vs Poverty'
scatter_plot.add('TX',tx_lst)
SVG(scatter_plot.render())

# %%
#For loop
for i in range(0,6,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
#Plots both lists together then set x label
scatter_plot=pygal.XY(stroke= False, x_title='Population Density',y_title='Poverty')
scatter_plot.xrange=(0,100) #can be placed in pygal.XY as an argument to reduce codes of line
scatter_plot.title = 'Population Density vs Poverty'
#sets x & y label code using a for loop, manually but it does not do automatic resize
#scatter_plot.x_labels = (i for i in range (0,2000,100))
#scatter_plot.y_labels = (i for i in range (0,45,2))
scatter_plot.add('TX',tx_lst)
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
al = health_data.loc[health_data['State'] == 'CA', ['Poverty']]
poverty_mean_al = al['Poverty'].mean()
poverty_mean_al
# Out:
# 12.868965517241376

# %%
#create a function with two arguments needed to function, output is the mean of the requested column from the state
def mean_of_column (state_name, column_name):
    state_df = health_data.loc[health_data['State'] == state_name, [column_name]]
    return state_df[column_name].mean()
mean_of_column('CA', 'Poverty')
# Out:
# 12.868965517241376

# %%
#.unique
health_data['State'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
#vertical Bar
bar_chart = pygal.Bar()
bar_chart.title = 'Mean of Poverty across all States'
for state in list (health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())

# %%
#Horizontal Bar
bar_chart = pygal.HorizontalBar(legend_at_bottom = True, legend_at_bottom_columns =11)
bar_chart.title = 'Mean of Poverty across all States'
for state in list (health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())
